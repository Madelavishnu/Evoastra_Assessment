# %% [markdown]
# <a href="https://colab.research.google.com/github/Madelavishnu/Evoastra_Assessment/blob/main/Vishnu_Evoastra_Assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Evoastra Ventures Intern Assessment Task
# **Duration: 35 Minutes | Total Points: 100**
#
# ---

# %% [markdown]
# ## **Candidate Information**
#
# **Fill in your details below:**
# - **Name:** Madela Vishnu Sai Teja
# - **Email:** vishnumadel45@gmail.com
# - **Phone:** 7032011053
# - **College/University:** Acharya NagarjunaUniversity
# - **Course/Branch:** Artificial Intelligence and Machine Learning
# - **Start Time:** 20/12/2025
# - **End Time:** 20/01/2026
# - **Git Hub Link:** https://github.com/Madelavishnu

# %% [markdown]
# ## **Dataset for Assessment**
#
# **E-commerce Customer Behavior Dataset**
# - **Direct Link:** https://www.kaggle.com/datasets/shriyashjagtap/e-commerce-customer-for-behavior-analysis
#
# **Dataset Columns:**
# - **Customer ID:** Unique identifier for each customer
# - **Customer Name:** Name of the customer
# - **Customer Age:** Age of the customer
# - **Gender:** Gender of the customer
# - **Purchase Date:** Date of each purchase
# - **Product Category:** Category of the purchased product
# - **Product Price:** Price of the purchased product
# - **Quantity:** Quantity of product purchased
# - **Total Purchase Amount:** Total amount spent in each transaction
# - **Payment Method:** Payment method used (credit card, PayPal, etc.)
# - **Returns:** Whether customer returned products (0 = No, 1 = Yes)
# - **Churn:** Whether customer has churned (0 = Retained, 1 = Churned)

# %% [markdown]
# ---
# ## **SECTION A: Data Understanding & Basic Analysis (25 Points - 10 Minutes)**

# %% [markdown]
# ### Question 1 (8 points)
# Based on the dataset structure, identify the **data types** for the following columns and explain why each classification is important for analysis:
#
# - **Customer Age**
# - **Gender**
# - **Total Purchase Amount**
# - **Churn**

# %%
# Your Answer for Question 1
# Customer Age: dtype = int64

# Gender: dtype = object

# Total Purchase Amount: dtype = int64

# Churn: dtype = int64

'''
Generally, a dataset contains multiple columns with different data types, so it is
important to understand the data before performing analysis. Data understanding helps
in visualization, preprocessing, and selecting appropriate statistical techniques.

During preprocessing, missing (NULL) values are handled based on the data type and
distribution of the column:

* If a column is numerical (integer or float) and follows a normal distribution, the
  missing values are filled using the mean.

* If a numerical column shows a skewed distribution, the median is preferred to
  avoid the effect of outliers.

* If a column is categorical (object type), the missing values are filled using the
  mode, as it represents the most frequent category.

The dataset is stored in a structured format, and Pandas displays data types such as
int64 and float64 because it internally uses NumPy arrays. By default, NumPy stores
integer values as int64 and decimal values as float64.

When the data is converted into PyTorch tensors, input features are typically converted
to float32, since most neural network layers such as nn.Linear require floating-point
tensors and GPUs are optimized for float32 computations.

'''

# %% [markdown]
# ### Question 2 (8 points)
# Which **analytical technique** would be most appropriate for each business question below?
#
# a) "Which product categories generate the highest revenue?"
# b) "Can we predict customer churn based on purchase behavior?"
# c) "What is the relationship between customer age and spending patterns?"
# d) "Which payment methods are preferred by different customer segments?"

# %%
# Your Answer for Question 2
# a) Product categories with highest revenue:  help us to summarize the dataDescriptive Analysis
    '''  Descriptive Analysis is help us to Summerize data.By aggregating total revenue means
     by product category using such as average and sum, we can easily identify which categories contribute
    the most to overall revenue. '''

# b) Predicting customer churn: Classification Analysis
    ''' Here  the prediction a binary Outcome is (churn or not Churn).
    Classification Models such as Logestic Regression(0-1), Desicion Trees, or Neural Networks
    can be used to predict customer churn based on purchase behaviour features.'''

# c) Age and spending relationship: Correlation Analysis
    ''' By using the Correlation analysis and scatter plots are used to understand the relationship
    between two numerical variables. This helps identify whether customer age has a
    positive, negative, or no relationship with spending patterns '''

# d) Payment method preferences: Segmentation Analysis
     ''' Segmentation analysis groups customers based on similar characteristics such as
     age, spending, or purchase behavior. Analyzing payment method usage within each segment helps
     identify preferences among different customer groups.'''

# %% [markdown]
# ### Question 3 (9 points)
# **Data Quality Assessment:** What are the top 3 potential data quality issues you would check for in this e-commerce dataset before starting analysis? For each issue, suggest one method to detect it.

# %%
# Your Answer for Question 3
# Issue 1: Missing Values in given data for each columns

# Detection Method 1: data.isnull().sum()
  ''' that method is help us to see total no of missing values are there in each column'''

# Issue 2: Duplicates in given data

# Detection Method 2:  data.duplicated().sum()
  ''' This method is help us to see total no of duplicates are there in given data'''

# Issue 3: Outliers

# Detection Method 3:  data.describe()
  ''' This method is help us give the all inforamtion about your data and it help us to understand
  easily where you did wrong'''

''' All these methods are help us to preprocessing or cleaning the data and one more thing
make sure data is in maximum numerical form because in that way on machine can understand '''

# %% [markdown]
# ---
# ## **SECTION B: Customer Analysis & Business Intelligence (35 Points - 15 Minutes)**

# %% [markdown]
# ### Scenario: E-commerce Revenue Analysis
#
# Based on the dataset structure, assume you have the following customer insights:
#
# **Customer Segments by Age:**
# - **Young (18-30):** 40% of customers, Average Purchase Amount: ₹850, Return Rate: 12%
# - **Middle-aged (31-50):** 45% of customers, Average Purchase Amount: ₹1,200, Return Rate: 8%
# - **Senior (51+):** 15% of customers, Average Purchase Amount: ₹950, Return Rate: 15%
#
# **Additional Information:**
# - Average customer acquisition cost: ₹180
# - Platform profit margin: 20% of purchase amount
# - Customer churn rates: Young (25%), Middle-aged (15%), Senior (30%)

# %% [markdown]
# ### Question 4 (15 points)
# **Calculate and analyze:**
#
# a) Which customer segment generates the highest **net profit per customer** (considering returns)? Show your calculations. (8 points)
#
# b) Which segment has the **best customer lifetime value** considering churn rates? Provide reasoning. (7 points)

# %% [markdown]
# ### Young Customer :
#
# Average Purchase Amount = ₹850
# Return Rate = 12%
#
# Effective Purchase = 850 × (1 − 0.12)
#                    = 850 × 0.88
#                    = ₹748
#
# Gross Profit = 748 × 0.20
#              = ₹149.6
#
# Net Profit per Customer = 149.6 − 180
#                         = ₹ −30.4 (Loss)
#
#
# ### Middle -aged Customer:
#
#
# Average Purchase Amount = ₹1200
# Return Rate = 8%
#
# Effective Purchase = 1200 × (1 − 0.08)
#                    = 1200 × 0.92
#                    = ₹1104
#
# Gross Profit = 1104 × 0.20
#              = ₹220.8
#
# Net Profit per Customer = 220.8 − 180
#                         = ₹40.8 (Profit)
#
#
#
# ### Senior Customers :
#
# Average Purchase Amount = ₹950
# Return Rate = 15%
#
# Effective Purchase = 950 × (1 − 0.15)
#                    = 950 × 0.85
#                    = ₹807.5
#
# Gross Profit = 807.5 × 0.20
#              = ₹161.5
#
# Net Profit per Customer = 161.5 − 180
#                         = ₹ −18.5 (Loss)

# %%
# Your Calculations for Question 4

# a) Net profit per customer calculations:

# Young Customers: ₹ −30.4 (Loss)


# Middle-aged Customers: ₹40.8 (Profit)

# Senior Customers:  ₹ −18.5 (Loss)



# b) Customer Lifetime Value Analysis:
''' The Middle-aged (31–50) customer segment has the highest net profit per customer and the lowest churn rate.
Therefore, it generates the highest Customer Lifetime Value.
'''

# %% [markdown]
# ### Question 5 (10 points)
# **Strategic Recommendations:** Based on your analysis, what would be your **top 2 marketing strategies** to maximize overall profitability? Consider customer acquisition, retention, and return rates.

# %%
# Your Answer for Question 5

# Strategy 1:
 ''' Focus on Retention and Upselling of Middle-aged Customers (31–50) :

* The Middle-aged segment generates the highest net profit per customer and has
  the lowest churn rate (15%).

* Marketing efforts such as personalized recommendations, loyalty programs, and
  subscription-based discounts should be targeted at this segment.

* Retaining these customers is cost-effective because acquisition cost is already
  covered and repeat purchases increase Customer Lifetime Value (CLV).

* Upselling and cross-selling higher-value products can further improve profitability
  with minimal increase in return rates.'''

# Strategy 2:
''' Reduce Return Rates and Churn in Young and Senior Segments :

* Young and Senior customers currently generate net losses due to high return rates
  and higher churn.

* Strategies such as improved product descriptions, size guides, better customer
  support, and flexible but controlled return policies can reduce unnecessary returns.

* Retention campaigns like onboarding offers, post-purchase engagement, and
  targeted discounts can help reduce churn.

* Lowering return rates and churn in these segments can convert loss-making
  customers into profitable ones without significantly increasing acquisition costs.
  '''

# %% [markdown]
# ### Question 6 (10 points)
# **Churn Prevention:** You notice that customers who make purchases in the "Electronics" category have a 35% churn rate, while "Fashion" category customers have only 18% churn rate. What **specific data analysis** would you conduct using the available dataset columns to understand this difference, and what **action plan** would you recommend?

# %%
# Your Answer for Question 6

# Data Analysis Plan:
'''

1. Category-wise Churn Analysis

   * Group customers by product_category and calculate churn rate for each category.

   * This confirms and quantifies churn differences between Electronics and Fashion.

2. Return Rate Comparison

   * Analyze the relationship between returns and product_category.

   * Higher return rates in Electronics may explain higher churn.

3. Purchase Value & Frequency Analysis

   * Compare product_price, quantity, and total_purchase_amount across categories.

   * Electronics purchases are typically high-value and infrequent, which may lead to dissatisfaction or post-purchase regret.

4. Payment Method Impact

   * Analyze churn rates by payment_method within Electronics and Fashion.

   * Certain payment methods may be linked to higher churn due to refund delays or payment issues.

5. Customer Demographics Analysis

   * Examine customer_age and gender distributions for Electronics vs Fashion buyers.

   * Demographic differences may influence expectations and churn behavior.'''

# Action Plan:
'''

1. Reduce Returns in Electronics

    * Improve product descriptions, technical specifications, warranty information, and customer reviews.

    * Offer virtual demos or comparison tools to reduce wrong purchases.

2. Post-Purchase Engagement for Electronics Customers

    * Send setup guides, usage tips, and customer support follow-ups after purchase.

    * Early engagement can reduce dissatisfaction and churn.

3. Flexible Exchange over Refunds

    * Encourage exchanges or store credits instead of refunds to retain customers.

4. Targeted Retention Campaigns

    * Provide loyalty points, extended warranties, or service discounts to Electronics buyers.
    '''

# %% [markdown]
# ---
# ## **SECTION C: Research Methodology & Predictive Analytics (25 Points - 8 Minutes)**

# %% [markdown]
# ### Scenario: Churn Prediction Model Development
#
# Your company wants to build a machine learning model to predict customer churn using the available dataset.

# %% [markdown]
# ### Question 7 (15 points)
# **Model Development Plan:** Create a comprehensive approach including:
#
# a) **Feature selection:** Which columns from the dataset would you use as features for the churn prediction model and why? (5 points)
# b) **Data preprocessing steps:** What preprocessing would you apply to prepare the data? (5 points)
# c) **Model evaluation metrics:** Which metrics would you use to evaluate model performance for this business problem? (5 points)

# %%
# Your Answer for Question 7

# a) Feature Selection:
'''
* Customer Age – Helps identify churn tendencies across different age groups.

* Gender – Useful for detecting demographic-based behavior differences.

* Product Category – Different categories (e.g., Electronics, Fashion) have different churn rates.

* Product Price – High-priced items may increase return probability and churn.

* Quantity – Indicates purchase volume and engagement level.

* Total Purchase Amount – Reflects overall spending behavior of the customer.

* Payment Method – Certain payment methods may be associated with higher churn due to refund or transaction issues.

* Returns – Strong indicator of dissatisfaction and churn likelihood.

Target Variable:

Churn (0 = Not churned, 1 = Churned)
'''

# b) Data Preprocessing Steps:
'''
1. Handling Missing Values

    * Numerical columns: fill using mean or median.

    * Categorical columns: fill using mode.

2. Encoding Categorical Variables

    * Apply one-hot encoding to columns such as gender, product category, and payment method.

3. Feature Scaling

    * Normalize or standardize numerical features like customer age, product price, quantity, and total purchase amount.

4. Outlier Treatment

    * Detect and cap or remove extreme values in spending-related columns.

5. Train-Test Split

    * Split data into training and testing sets to evaluate model generalization.
'''

# c) Model Evaluation Metrics:

'''
Since churn prediction is a classification problem with business impact, the following metrics would be used:

* Accuracy – Measures overall correctness of predictions.

* Precision – Important to reduce false churn predictions.

* Recall – Crucial for identifying actual churners and preventing revenue loss.

* F1-Score – Balances precision and recall for imbalanced data.

* ROC-AUC Score – Measures model’s ability to distinguish between churned and non-churned customers.
'''

# %% [markdown]
# ### Question 8 (10 points)
# **Business Impact Analysis:** Identify 3 potential business challenges in implementing a churn prediction model and propose one **data-driven solution** for each challenge using insights from the customer behavior dataset.

# %%
# Your Answer for Question 8

# Challenge 1: High Return Rates Affecting Model Reliability
# Data-driven Solution 1:
'''Perform category-wise churn and return analysis using product_category and returns.'''

# Challenge 2: Even a well-performing model may fail if business teams do not trust or understand its predictions.
# Data-driven Solution 2:
'''Use model explainability techniques (e.g., feature importance) to show how factors
like customer_age, total_purchase_amount, and returns influence churn.'''

# Challenge 3: If the churn model incorrectly labels loyal customers as churn-risk, the company may spend money on unnecessary retention offers, reducing profitability.
# Data-driven Solution 3:
'''Use precision-recall analysis and adjust the churn probability threshold based on
   business cost.
'''

# %% [markdown]
# ---
# ## **SECTION D: Professional Communication & Problem-Solving (15 Points - 2 Minutes)**

# %% [markdown]
# ### Question 9 (8 points)
# **Crisis Management:** While analyzing the dataset, you discover that 40% of customers who returned products (Returns = 1) also churned within the same month. However, your initial analysis showed returns don't strongly correlate with churn. As a team member, describe your immediate approach to investigate this discrepancy and communicate findings to stakeholders (60-80 words).

# %%
# Your Answer for Question 9 (60-80 words)
'''
If I notice this mismatch, I would first double-check the data to make sure the
numbers are correct, especially the timing between returns and churn. I’d then
break the data down by product category and customer segment to see if the issue
is happening in specific cases. Once confirmed, I’d explain the findings in simple
terms to stakeholders and suggest quick actions like focused follow-ups for high-risk customers.
'''

# %% [markdown]
# ### Question 10 (7 points)
# **Leadership Scenario:** If selected as team lead for analyzing this e-commerce customer dataset, what would be your **top 3 priorities** to ensure effective team collaboration and delivery of actionable business insights?

# %%
# Your Answer for Question 10

# Priority 1:
'''
Clear Problem Definition and Goal Alignment

Make sure the team clearly understands the business objective, such as reducing
customer churn or improving revenue. Aligning everyone on the same goal helps avoid
confusion and keeps the analysis focused and meaningful.'''

# Priority 2:
'''
Effective Communication and Task Coordination

Divide work based on individual strengths and maintain regular check-ins to track
progress. Open communication ensures issues are identified early and collaboration
stays smooth.
'''
# Priority 3:
'''
Turning Data Insights into Actionable Recommendations

Focus on converting analysis results into simple, practical insights that business
teams can act on. Present findings clearly using visuals and summaries so decisions
can be made quickly.
'''

# %% [markdown]
# ---
# ## **Self-Assessment Section**

# %%
# Time Management Check
# Did you complete all sections within 35 minutes? (Yes/No): No

# Which section took the most time? : I Think it's 6th question

# Which section was most challenging? : It's 4th , i need to do math for that

# Confidence Level (1-10 scale):
# Section A (Data Understanding): 9
# Section B (Business Analysis): 7
# Section C (Research Methodology):7
# Section D (Communication):7

# Additional Comments:

'''
it's a good exerrcise for me . this help me to good understanding about the data and tells how
machine learning work . i have got good experience from them'''

# %% [markdown]
# # 🗝️**Full code Link**:
#
# https://github.com/Madelavishnu/Evoastra_Assessment/blob/main/E_Commerce_dataset.ipynb

# %% [markdown]
# ---
# ## **Submission Instructions**
#
# 1. **Save this notebook** with the filename: `YourName_Evoastra_Assessment.ipynb`
# 2. **Ensure all code cells have been executed** and answers are visible
# 3. **Double-check** that all sections are completed
#
# **Submission Confirmation:**
# - I confirm that I have completed this assessment independently
# - All my responses are my own original work
#
# **Digital Signature:** *vishnu...*
#
# **Final Submission Time:** 26/12/2025

# %% [markdown]
# ---
# ## **Evaluation Criteria**
#
# **Scoring Breakdown:**
# - **Section A (Data Understanding):** 25 points
# - **Section B (Business Analysis):** 35 points
# - **Section C (Research Methodology):** 25 points
# - **Section D (Communication):** 15 points
# - **Total:** 100 points
#
# **Team Selection Criteria:**
# - **Team Lead:** Score ≥ 75 points + Strong Section D performance
# - **Co-Lead:** Score ≥ 65 points + Good Section D performance
# - **Team Member:** Successful completion of assessment
#
# ---
#
# *Good luck with your assessment! Focus on clear reasoning, accurate calculations, and practical business applications.*
